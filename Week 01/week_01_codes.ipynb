# %%
print("Hello")
# Out:
# Hello

# %%
a = 100
print(a)
print(type(a))
# Out:
# 100
# <class 'int'>

# %%
name = "ShaluBro"
print(name)
print(type(name))
# Out:
# ShaluBro
# <class 'str'>

# %%
PI_VALUE = 3.14
print(PI_VALUE)
print(type(PI_VALUE))
# Out:
# 3.14
# <class 'float'>

# %%
is_present = True
print(is_present)
print(type(is_present))
# Out:
# True
# <class 'bool'>

# %%
c = 10+ 50j
print(c)
print(type(c))
# Out:
# (10+50j)
# <class 'complex'>

# %%
x = 10
y = 2.5

a = float(x) # convert from int to float
b = int(y) # convert from float to int

print(a)
print(type(a))
print(b)
print(type(b))
# Out:
# 10.0
# <class 'float'>
# 2
# <class 'int'>

# %%
marks = "85.5"
marks_float = float(marks)
print(marks_float+4.5)
# Out:
# 90.0

# %%
a = "10"
b = "20"
c = "30"

a = int(a)
b = int(b)
c = int(c)

print(a+b+c)
# Out:
# 60

# %%
height = input("Enter you height cm: ")

height = int(height)
calculate = height / 100

print(calculate)
# Out:
# 1.5

# %%
weight = input("Enter your weight in KG: ")
height = input("Enter your height in cm: ")

weight = float(weight)
height = float(height)

height_m = height/100

BMI = (weight/(height_m**2))

print("Weight: ", weight,"kg")
print("Height: ", height_m,"m")
print("BMI", BMI)
# Out:
# Weight:  55.0 kg
# Height:  2.5 m
# BMI 8.8

# %%
my_list = ["car", "bike", "bus"]
print(my_list)
print(type(my_list))
# Out:
# ['car', 'bike', 'bus']
# <class 'list'>

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list)
print(id(my_list))

my_list[0] = 10
print(my_list)
print(id(my_list))
print(len(my_list))
print(my_list[2])
print(my_list[-1])
print(my_list[-2])
# Out:
# [1, 2, 3, 4, 5]
# 3086574194368
# [10, 2, 3, 4, 5]
# 3086574194368
# 5
# 3
# 5
# 4

# %%
my_list = [True, False, True, False]
print(my_list)
print(type(my_list))
print(my_list[0])
print(my_list[-1]) # Negative Indexing
# Out:
# [True, False, True, False]
# <class 'list'>
# True
# False

# %%
my_list = ["car", "bike", "bus", "train", "plane", "boat"]
print(my_list[2:5])
print(my_list[:3])
print(my_list[2:])
# Out:
# ['bus', 'train', 'plane']
# ['car', 'bike', 'bus']
# ['bus', 'train', 'plane', 'boat']

# %%
my_list = ["dog", "cat", "lion", "elephant", "rat", "fish"]
my_list[1] = "tiger"
print(my_list)
# Out:
# ['dog', 'tiger', 'lion', 'elephant', 'rat', 'fish']

# %%
my_list = ["dog", "cat", "lion", "elephant", "rat", "fish"]
my_list[1:3] = ["zebra", "tiger"]
print(my_list)
# Out:
# ['dog', 'zebra', 'tiger', 'elephant', 'rat', 'fish']

# %%
my_list = ["car", "bike", "bus", "train"]
my_list.insert(2, "plane")
print(my_list)
# Out:
# ['car', 'bike', 'plane', 'bus', 'train']

# %%
my_list = ["car", "bike", "bus", "train"]
my_list.append("plane")
print(my_list)
# Out:
# ['car', 'bike', 'bus', 'train', 'plane']
